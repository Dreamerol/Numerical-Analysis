# %%
import matplotlib.pyplot as plt
import numpy as np

def divided_difference(nodes, values, x):
    n = len(nodes)
    if n == 1:
        return values[0]
    return (divided_difference(nodes[1:], values[1:], x) - divided_difference(nodes[0:-1], values[0:-1], x))/(nodes[-1] - nodes[0])

    
def newton_Poly(nodes, values, x):
    p = 0
    n = len(nodes)
    for i in range(0, n):
        q = divided_difference(nodes[0:i+1], values[0:i+1], x)
       
        p += q * pro
    return p
    
def newton_Poly(nodes, values, x):
    p = 0
    n = len(nodes)
    for i in range(0, n):
        q = divided_difference(nodes[0:i+1], values[0:i+1], x)
        for j in range(0, i):
             q *= (x-nodes[j]) 
        p += q
    return p
