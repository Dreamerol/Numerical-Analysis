# %%
import math
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-1,1,100)
               
def T(n,x):
    return np.cos(n*np.arccos(x))

for i in range(5):
    plt.plot(x, T(i, x), label = 'T' + str(i) + "(x)")
plt.legend()
    #stepenite na polinoma
